# %% [markdown]
# # MEDICAL INSURANCE PREMIUM PREDICTION
#
#
# ```

# %% [markdown]
# https://www.kaggle.com/datasets/mirichoi0218/insurance:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('/content/insurance.csv')

# %% [markdown]
#  Data exploration

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
from matplotlib import pyplot as plt
_df_0['age'].plot(kind='hist', bins=20, title='age')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
dataset.describe()
# Out:
#                age          bmi     children       charges     sex_male  \
# count  1338.000000  1338.000000  1338.000000   1338.000000  1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265     0.505232
# std      14.049960     6.098187     1.205493  12110.011237     0.500160
# min      18.000000    15.960000     0.000000   1121.873900     0.000000
# 25%      27.000000    26.296250     0.000000   4740.287150     0.000000
# 50%      39.000000    30.400000     1.000000   9382.033000     1.000000
# 75%      51.000000    34.693750     2.000000  16639.912515     1.000000
# max      64.000000    53.130000     5.000000  63770.428010     1.000000
#
#         smoker_yes  region_northwest  region_southeast  region_southwest
# count  1338.000000       1338.000000       1338.000000       1338.000000
# mean      0.204783          0.242900          0.272048          0.242900
# std       0.403694          0.428995          0.445181          0.428995
# min       0.000000          0.000000          0.000000          0.000000
# 25%       0.000000          0.000000          0.000000          0.000000
# 50%       0.000000          0.000000          0.000000          0.000000
# 75%       0.000000          0.000000          1.000000          0.000000
# max       1.000000          1.000000          1.000000          1.000000

# %%
from matplotlib import pyplot as plt
_df_28['age'].plot(kind='line', figsize=(8, 4), title='age')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
dataset.shape
# Out:
# (1338, 7)

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
len(dataset.select_dtypes(include='object').columns)
# Out:
# 3

# %%
dataset.select_dtypes(include=['int64', 'float64']).columns
# Out:
# Index(['age', 'bmi', 'children', 'charges'], dtype='object')

# %%
len(dataset.select_dtypes(include=['int64', 'float64']).columns)
# Out:
# 4

# %%
dataset.groupby('smoker').mean()
# Out:
# <ipython-input-15-7a7d40b4bb92>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset.groupby('smoker').mean()
#               age        bmi  children       charges
# smoker
# no      39.385338  30.651795  1.090226   8434.268298
# yes     38.514599  30.708449  1.113139  32050.231832
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_36['age'].plot(kind='hist', bins=20, title='age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_37['bmi'].plot(kind='hist', bins=20, title='bmi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_38['children'].plot(kind='hist', bins=20, title='children')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_39['charges'].plot(kind='hist', bins=20, title='charges')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_40.plot(kind='scatter', x='age', y='bmi', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_41.plot(kind='scatter', x='bmi', y='children', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_42.plot(kind='scatter', x='children', y='charges', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['bmi']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_43.sort_values('bmi', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('bmi')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['bmi']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'bmi'}, axis=1)
#               .sort_values('bmi', ascending=True))
#   xs = counted['bmi']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_44.sort_values('bmi', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('bmi')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['children']
#   ys = series['age']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_45.sort_values('children', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('children')
# _ = plt.ylabel('age')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['children']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'children'}, axis=1)
#               .sort_values('children', ascending=True))
#   xs = counted['children']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_46.sort_values('children', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('children')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_47['age'].plot(kind='line', figsize=(8, 4), title='age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_48['bmi'].plot(kind='line', figsize=(8, 4), title='bmi')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_49['children'].plot(kind='line', figsize=(8, 4), title='children')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_50['charges'].plot(kind='line', figsize=(8, 4), title='charges')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['bmi']
  ys = series['age']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_43.sort_values('bmi', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('bmi')
_ = plt.ylabel('age')

# %%
dataset.groupby('region').mean()
# Out:
# <ipython-input-16-a56bc4f3bc6a>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset.groupby('region').mean()
#                  age        bmi  children       charges
# region
# northeast  39.268519  29.173503  1.046296  13406.384516
# northwest  39.196923  29.199785  1.147692  12417.575374
# southeast  38.939560  33.355989  1.049451  14735.411438
# southwest  39.455385  30.596615  1.141538  12346.937377

# %% [markdown]
# Dealing with missing values

# %%
dataset.isnull().values.any()
# Out:
# False

# %%
dataset.isnull().values.sum()
# Out:
# 0

# %% [markdown]
# Encoding the categorical data

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index(['sex', 'smoker', 'region'], dtype='object')

# %%
dataset['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
dataset['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
dataset['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_55.groupby('sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
dataset = pd.get_dummies(data=dataset, drop_first=True)

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
dataset.shape
# Out:
# (1338, 9)

# %% [markdown]
# ## Correlation matrix

# %%
dataset_2 = dataset.drop(columns='charges')

# %%
dataset_2.corrwith(dataset['charges']).plot.bar(
    figsize=(16,9), title='Correlation with Charges', rot=45, grid=True
)
# Out:
# <Axes: title={'center': 'Correlation with Charges'}>

# %%
corr = dataset.corr()

# %%
# heatmap
plt.figure(figsize=(16, 9))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Splitting the dataset

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
x = dataset.drop(columns='charges')

# %%
y = dataset['charges']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x_train.shape
# Out:
# (1070, 8)

# %%
y_train.shape
# Out:
# (1070,)

# %%
x_test.shape
# Out:
# (268, 8)

# %%
y_test.shape
# Out:
# (268,)

# %% [markdown]
# ## Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-0.14853305,  0.54530479,  2.41394802, ..., -0.55791981,
#         -0.6155209 ,  1.70862925],
#        [-1.49780784,  0.59867181, -0.89219519, ..., -0.55791981,
#          1.6246402 , -0.58526447],
#        [-1.14273553,  0.96092064,  0.76087642, ..., -0.55791981,
#         -0.6155209 , -0.58526447],
#        ...,
#        [ 0.06451033, -0.91339361, -0.89219519, ..., -0.55791981,
#          1.6246402 , -0.58526447],
#        [-1.42679338,  0.77656186, -0.89219519, ...,  1.79237229,
#         -0.6155209 , -0.58526447],
#        [-0.4325909 , -1.97749955, -0.06565939, ..., -0.55791981,
#         -0.6155209 ,  1.70862925]])

# %%
x_test
# Out:
# array([[ 0.91668389, -0.08539629, -0.06565939, ..., -0.55791981,
#         -0.6155209 ,  1.70862925],
#        [ 0.56161157, -0.21962242, -0.06565939, ..., -0.55791981,
#          1.6246402 , -0.58526447],
#        [ 0.63262604,  1.59081313,  0.76087642, ...,  1.79237229,
#         -0.6155209 , -0.58526447],
#        ...,
#        [ 1.2717562 ,  1.54472343, -0.89219519, ..., -0.55791981,
#         -0.6155209 , -0.58526447],
#        [-0.64563429,  1.34581001,  1.58741222, ..., -0.55791981,
#          1.6246402 , -0.58526447],
#        [ 0.49059711, -0.95948331,  1.58741222, ..., -0.55791981,
#         -0.6155209 , -0.58526447]])

# %% [markdown]
# Building model

# %% [markdown]
# linear regression

# %%
from sklearn.linear_model import LinearRegression
regressor_lr = LinearRegression()
regressor_lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor_lr.predict(x_test)

# %%
from sklearn.metrics import  r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7999876970680433

# %% [markdown]
# Random forest regression

# %%
from sklearn.ensemble import RandomForestRegressor
regressor_rf = RandomForestRegressor()
regressor_rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor_rf.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8763217431329968

# %% [markdown]
# XG BOOST REGRESSION

# %%
from xgboost import XGBRFRegressor
regressor_xgb = XGBRFRegressor()
regressor_xgb.fit(x_train, y_train)
# Out:
# XGBRFRegressor(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bytree=None, device=None,
#                early_stopping_rounds=None, enable_categorical=False,
#                eval_metric=None, feature_types=None, gamma=None,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=None, max_leaves=None,
#                min_child_weight=None, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=None, n_jobs=None,
#                num_parallel_tree=None, objective='reg:squarederror',
#                random_state=None, reg_alpha=None, ...)

# %%
y_pred = regressor_xgb.predict(x_test)

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8994492709535864

# %% [markdown]
# PREDICTING CHARGES FOR BRAND  NEW CUSTOMER

# %% [markdown]
# NEW CUSTOMER
# Name: Frank, age: 40, sex: 1, bmi:45.50, children:4, smoker:1, region:northeast

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
frank_obs = [[40, 45.5, 4, 1, 1, 0, 0, 0]]

# %%
regressor_xgb.predict(sc.transform(frank_obs))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([43421.676], dtype=float32)

# %% [markdown]
# Name: Sara, age:19, bmi:27.9, children:0, sex:female, smoker:no, region: northwest

# %%
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0  16884.92400         0           1                 0
# 1   18  33.770         1   1725.55230         1           0                 0
# 2   28  33.000         3   4449.46200         1           0                 0
# 3   33  22.705         0  21984.47061         1           0                 1
# 4   32  28.880         0   3866.85520         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
sara_obs = [[19, 27.9, 0, 0, 0, 1, 0, 0]]

# %%
sara_obs
# Out:
# [[19, 27.9, 0, 0, 0, 1, 0, 0]]

# %%
regressor_xgb.predict(sc.transform(sara_obs))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([2374.3804], dtype=float32)
